# %% [markdown]
# # Visualizations associated with "Metagenomics of Cheese Rind Microbial Communities"
#
# This notebook demonstrates how the figures in this pub were created.

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-apple-darwin13.4.0 (64-bit)
# Running under: macOS Big Sur ... 10.16
#
# Matrix products: default
# BLAS/LAPACK: /Users/emilycpweiss/miniconda3/envs/tidyjupyter/lib/libopenblasp-r0.3.21.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] sourmashconsumr_0.1.0 ComplexUpset_1.3.3    ggpubr_0.5.0
#  [4] ggthemes_4.2.4        ggplot2_3.4.0         tibble_3.1.8
#  [7] purrr_1.0.1           tidyr_1.3.0           dplyr_1.1.0
# [10] readr_2.1.3
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-9      tidyselect_1.2.0  repr_1.1.6        carData_3.0-5
#  [5] colorspace_2.1-0  vctrs_0.5.2       generics_0.1.3    htmltools_0.5.4
#  [9] base64enc_0.1-3   utf8_1.2.3        rlang_1.0.6       pillar_1.8.1
# ...

# %% [markdown]
# # Plotting of metagenomic assembly stats
# This section reads in CSV files containing information about the metagenomic assemblies. These CSV files were created from information from the metaFlye output log and the QUAST web interface [ref].
#
# ## Plot the N50 values of the long and short read assemblies
# ### Long read

# %%
#load ggplot2
library(ggplot2)
# read-in data and plot
options(scipen = 999)
n50assem=read.csv("../processed_data/csv_tables_for_plotting/n50ass.csv")
n50assem
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=n50assem, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "N50 (bp)", x = "Sample")
#ELz12W is the same sample as EL12W, just renamed to preserve correct plotting order
# Out:
#    sample   len     type
# 1  OM2W      251305 Gridion
# 2  OM4W      206574 Gridion
# 3  OM8W      256457 Gridion
# 4  EL2W     1127027 Gridion
# 5  EL4W      823368 Gridion
# 6  ELz12W    220305 Gridion
# 7  WH1M       82606 Gridion
# 8  WH2M       69248 Gridion
# 9  WH4M      189473 Gridion
# 10 OM4W-WGA   35933 Gridion
# 11 EL4W-WGA   72921 Gridion
# 12 WH2M-WGA   85690 Gridion
# 13 AL4M       94805 Gridion
# 14 WHous2M    71337 Gridion
# 15 WI3W     1420506 Gridion
# plot without title

# %% [markdown]
# ### Short read

# %%
# read-in data and plot
options(scipen = 999)
n50assemill=read.csv("~/Desktop/n50assill.csv")
n50assemill
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=n50assemill, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#F7B846"))+theme_minimal()+theme(legend.position="none")+labs(y= "N50 (bp)", x = "Sample")
# Out:
#   sample len   type
# 1 OM2W   13978 Illumina
# 2 OM4W    4297 Illumina
# 3 OM8W    7663 Illumina
# 4 EL2W   19690 Illumina
# 5 EL4W   18605 Illumina
# 6 ELz12W  1880 Illumina
# 7 WH1M    4648 Illumina
# 8 WH2M    4308 Illumina
# 9 WH4M   14308 Illumina
# plot without title

# %% [markdown]
# ## Plot the longest contig of the long and short read assemblies
# ### Long read

# %%
# read-in data and plot
options(scipen = 999)
max=read.csv("~/Desktop/maxgrid.csv")
max
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=max, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "Longest Contig (bp)", x = "Sample")
# Out:
#    sample   len     type
# 1  OM2W     3928894 Gridion
# 2  OM4W     3933759 Gridion
# 3  OM8W     4456845 Gridion
# 4  EL2W     3926461 Gridion
# 5  EL4W     3928853 Gridion
# 6  ELz12W   4096232 Gridion
# 7  WH1M     3896469 Gridion
# 8  WH2M     3879948 Gridion
# 9  WH4M     3931379 Gridion
# 10 OM4W-WGA  517508 Gridion
# 11 EL4W-WGA 3791997 Gridion
# 12 WH2M-WGA 3780672 Gridion
# 13 AL4M     3901461 Gridion
# 14 WHous2M  3160752 Gridion
# 15 WI3W     3929106 Gridion
# plot without title

# %% [markdown]
# ### Short read

# %%
# read-in data and plot
options(scipen = 999)
max=read.csv("~/Desktop/maxill.csv")
max
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=max, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#F7B846"))+theme_minimal()+theme(legend.position="none")+labs(y= "Longest Contig (bp)", x = "Sample")
# Out:
#   sample len     type
# 1 OM2W   1401470 Illumina
# 2 OM4W    307364 Illumina
# 3 OM8W    434153 Illumina
# 4 EL2W    863861 Illumina
# 5 EL4W    610009 Illumina
# 6 ELz12W  270016 Illumina
# 7 WH1M    568683 Illumina
# 8 WH2M    403655 Illumina
# 9 WH4M    568683 Illumina
# plot without title

# %% [markdown]
# ## Plot the total assembly length of the long and short read assemblies
# ### Long read

# %%
# read-in data and plot
options(scipen = 999)
total=read.csv("~/Desktop/totallengrid.csv")
total
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=total, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "Total Assembly Length (bp)", x = "Sample")
# Out:
#    sample   len       type
# 1  OM2W      76984836 Gridion
# 2  OM4W      34025812 Gridion
# 3  OM8W      82653778 Gridion
# 4  EL2W      73348741 Gridion
# 5  EL4W      62551192 Gridion
# 6  ELz12W    68053988 Gridion
# 7  WH1M     101617845 Gridion
# 8  WH2M      90411903 Gridion
# 9  WH4M      85647949 Gridion
# 10 OM4W-WGA   8171585 Gridion
# 11 EL4W-WGA  27021306 Gridion
# 12 WH2M-WGA  51750955 Gridion
# 13 AL4M      90720377 Gridion
# 14 WHous2M   78347998 Gridion
# 15 WI3W      46826900 Gridion
# plot without title

# %% [markdown]
# ### Short read

# %%
# read-in data and plot
options(scipen = 999)
total=read.csv("~/Desktop/totallenill.csv")
total
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=total, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#F7B846"))+theme_minimal()+theme(legend.position="none")+labs(y= "Total Assembly Length (bp)", x = "Sample")
# Out:
#   sample len       type
# 1 OM2W   101565769 Illumina
# 2 OM4W    98337362 Illumina
# 3 OM8W   142142458 Illumina
# 4 EL2W   110704598 Illumina
# 5 EL4W    95750507 Illumina
# 6 ELz12W 138045698 Illumina
# 7 WH1M   179422618 Illumina
# 8 WH2M   191895440 Illumina
# 9 WH4M   141013421 Illumina
# plot without title

# %% [markdown]
# ## Plot the number of contigs in the long and short read assemblies
# ### Long read

# %%
# read-in data and plot
options(scipen = 999)
ctg=read.csv("~/Desktop/numctggrid.csv")
ctg
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=ctg, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "Number of Contigs", x = "Sample")
# Out:
#    sample   len  type
# 1  OM2W     1055 Gridion
# 2  OM4W     1446 Gridion
# 3  OM8W     1520 Gridion
# 4  EL2W     1712 Gridion
# 5  EL4W     1002 Gridion
# 6  ELz12W   1420 Gridion
# 7  WH1M     3667 Gridion
# 8  WH2M     6301 Gridion
# 9  WH4M     2299 Gridion
# 10 OM4W-WGA  635 Gridion
# 11 EL4W-WGA  859 Gridion
# 12 WH2M-WGA 1465 Gridion
# 13 AL4M     4041 Gridion
# 14 WHous2M  4336 Gridion
# 15 WI3W      793 Gridion
# plot without title

# %% [markdown]
# ### Short read

# %%
# read-in data and plot
options(scipen = 999)
ctg=read.csv("~/Desktop/numctgill.csv")
ctg
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=ctg, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#F7B846"))+theme_minimal()+theme(legend.position="none")+labs(y= "Number of Contigs", x = "Sample")
# Out:
#   sample len    type
# 1 OM2W    76065 Illumina
# 2 OM4W    82393 Illumina
# 3 OM8W   114271 Illumina
# 4 EL2W    96921 Illumina
# 5 EL4W    61586 Illumina
# 6 ELz12W 165858 Illumina
# 7 WH1M   210148 Illumina
# 8 WH2M   165477 Illumina
# 9 WH4M   116006 Illumina
# plot without title

# %% [markdown]
# ## Plot the number of predicted circular contigs in the long read assembly

# %%
# read-in data and plot
options(scipen = 999)
circ=read.csv("~/Desktop/circgrid.csv")
circ
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=circ, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "Number of Circular Contigs", x = "Sample")
# Out:
#    sample   len type
# 1  OM2W      76 Gridion
# 2  OM4W      70 Gridion
# 3  OM8W      98 Gridion
# 4  EL2W      82 Gridion
# 5  EL4W      59 Gridion
# 6  ELz12W   116 Gridion
# 7  WH1M     234 Gridion
# 8  WH2M     215 Gridion
# 9  WH4M     130 Gridion
# 10 OM4W-WGA  72 Gridion
# 11 EL4W-WGA  79 Gridion
# 12 WH2M-WGA 120 Gridion
# 13 AL4M     134 Gridion
# 14 WHous2M  217 Gridion
# 15 WI3W      41 Gridion
# plot without title

# %% [markdown]
# # Read Stats
# This section reads in CSV files containing information about the metagenomic sequencing reads. These CSV files were created from information from the ONT and Novogene sequencing reports.
#
# ## Plot the number of sequencing reads from long and short read sequencing
# ### Long read

# %%
# read-in data and plot
reads=read.csv("~/Desktop/gridreads.csv")
reads
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=reads, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "Number of Reads", x = "Sample")
# Out:
#    sample   len     type
# 1  OM2W     1809920 Gridion
# 2  OM4W     1195509 Gridion
# 3  OM8W     1243527 Gridion
# 4  EL2W     1365861 Gridion
# 5  EL4W     1185003 Gridion
# 6  ELz12W   1008150 Gridion
# 7  WH1M     1605959 Gridion
# 8  WH2M     1705799 Gridion
# 9  WH4M      995031 Gridion
# 10 OM4W-WGA  539685 Gridion
# 11 EL4W-WGA  440996 Gridion
# 12 WH2M-WGA  272848 Gridion
# 13 AL4M     1580429 Gridion
# 14 WHous2M  1717519 Gridion
# 15 WI3W      899279 Gridion
# plot without title

# %% [markdown]
# ### Short read

# %%
# read-in data and plot
options(scipen = 999)
reads=read.csv("~/Desktop/illreadnum.csv")
reads
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=reads, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#F7B846"))+theme_minimal()+theme(legend.position="none")+labs(y= "Number of Reads", x = "Sample")
# Out:
#   sample len       type
# 1 OM2W   113282802 Illumina
# 2 OM4W   110655420 Illumina
# 3 OM8W   114371630 Illumina
# 4 EL2W   108707260 Illumina
# 5 EL4W   143393884 Illumina
# 6 ELz12W 120479188 Illumina
# 7 WH1M   121499862 Illumina
# 8 WH2M   127046080 Illumina
# 9 WH4M   113813124 Illumina
# plot without title

# %% [markdown]
# ## Plot the N50 of sequencing reads from long read sequencing

# %%
# read-in data and plot
options(scipen = 999)
oreads=read.csv("~/Desktop/gridn50seq.csv")
oreads
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(data=oreads, aes(x=sample,y=len,fill=type)) + geom_bar(stat="identity", position=position_dodge())
p+scale_fill_manual(values = c("#7A77AB"))+theme_minimal()+theme(legend.position="none")+labs(y= "N50 of Reads (bp)", x = "Sample")
# Out:
#    sample   len  type
# 1  OM2W     8240 Gridion
# 2  OM4W     3880 Gridion
# 3  OM8W     8480 Gridion
# 4  EL2W     3710 Gridion
# 5  EL4W     5290 Gridion
# 6  ELz12W   6850 Gridion
# 7  WH1M     6080 Gridion
# 8  WH2M     2850 Gridion
# 9  WH4M     5480 Gridion
# 10 OM4W-WGA 8480 Gridion
# 11 EL4W-WGA 8060 Gridion
# 12 WH2M-WGA 9780 Gridion
# 13 AL4M     3590 Gridion
# 14 WHous2M  3670 Gridion
# 15 WI3W     3020 Gridion
# plot without title

# %% [markdown]
# # Sourmashconsumr analysis

# %% [markdown]
# This section uses functions from sourmashconsumr to visualize outputs from sourmash to compare samples and to look at taxonomy & abundance over time in Illumina metagenomic data.
#
# The 'sourmash sketch dna' command with -p flags k=31,scaled=1000 was used to make signatures for all metagenomic assemblies. The 'sourmash compare' command was then used to make a similarity matrix for the assemblies. The 'sourmash sketch dna' command with -p flags k=31,scaled=1000,abund was used to make signatures for paired-end Illumina read files. The 'sourmash gather' command with -k 31 and --scaled 1000 options was used for each of the nine Illumina read file signatures. For 'sourmash gather', the preprepared sourmash Genbank genomes from March 2022 k31 databases for viruses, bacteria, archaea, protozoa, and fungi, plus the custom 'cheesegenomes-k31-scaled1k' databases were used. The 'sourmash tax annotate' command was then used on the resulting gather files with the taxonomy sheets for these six databases. This resulted in nine sr.with-lineages.csv files.
# Sourmash version 4.6.1 was used.

# %%
#load libraries needed, source sourmashconsumr funcitons, and set a color scale
library(readr)
library(dplyr)
library(tidyr)
library(purrr)
library(tibble)
library(ggplot2)
library(ggthemes)
library(ggpubr)
library(ComplexUpset)
library(sourmashconsumr)
source("~/Downloads/untitled folder 2/2022-prjna853785-sourmash/scripts/utils.R")
accent_v2 = c('#5088C5', '#F28360', '#3B9886', '#F7B846', '#7A77AB', '#F898AE', '#C6E7F4', '#F8C5C1', '#B5BEA4','#F5E4BE', '#DCBFFC','#F5CBE4','#484B50',"lightblue","pink","goldenrod1")

# %% [markdown]
# ### Visualize sourmash compare output

# %%
#read in output from sourmash compare
compare <- read_csv("~/Downloads/compareabun.csv", show_col_types = F) %>%
  mutate(sample = colnames(.)) %>% # make column names into a column
  column_to_rownames("sample") %>% # set rownames to column names
  as.matrix() 
compare
compare_mds <- compare %>% 
  dist() %>%
  cmdscale() %>%
  as.data.frame() %>%
  rename(MDS1 = V1, MDS2 = V2) %>%
  rownames_to_column("sample")
compare_mds
# Out:
#        EL12LR     EL2LR       EL4LR       EL12SR     EL2SR      EL4SR
# EL12LR 1.00000000 0.195105121 0.237624419 0.38311282 0.18082245 0.194910757
# EL2LR  0.19510512 1.000000000 0.730540870 0.32430520 0.59912699 0.606378727
# EL4LR  0.23762442 0.730540870 1.000000000 0.35944544 0.56067115 0.597120527
# EL12SR 0.38311282 0.324305203 0.359445436 1.00000000 0.37188555 0.399290571
# EL2SR  0.18082245 0.599126986 0.560671145 0.37188555 1.00000000 0.678820614
# EL4SR  0.19491076 0.606378727 0.597120527 0.39929057 0.67882061 1.000000000
# OM2SR  0.15339863 0.577954791 0.543374855 0.33560217 0.61118871 0.624556720
# OM4SR  0.20515811 0.494024417 0.511121340 0.37908436 0.57210436 0.577520723
# OM8SR  0.22381096 0.431636479 0.456081395 0.40646213 0.48258452 0.499235349
# WH1SR  0.06805409 0.038954622 0.006566867 0.10122033 0.05480076 0.050664933
# WH2SR  0.06074639 0.030156428 0.005355274 0.09705836 0.04540868 0.039816437
# ...

# %%
# Add metadata columns
compare_mds$tech=c("zl","zl","zl","s","s","s","s","s","s","s","s","s","zl","zl","zl","zl","zl","zl") #short or long read
compare_mds$age=c("zlate","early","middle","zlate","early","middle","early","middle","zlate","early","middle","zlate","early","zlate","middle","early","middle","zlate")
compare_mds$cheese=c("e","e","e","e","e","e","o","o","o","w","w","w","o","o","o","w","w","w")
compare_mds
# Out:
#    sample MDS1       MDS2        tech age    cheese
# 1  EL12LR  0.1173985  0.86357486 zl   zlate  e
# 2  EL2LR  -0.9286368 -0.15189413 zl   early  e
# 3  EL4LR  -0.9431706 -0.06166405 zl   middle e
# 4  EL12SR -0.2466144  0.32805360 s    zlate  e
# 5  EL2SR  -0.8627590 -0.20149449 s    early  e
# 6  EL4SR  -0.9066740 -0.19154223 s    middle e
# 7  OM2SR  -0.8815896 -0.24803150 s    early  o
# 8  OM4SR  -0.7943894 -0.11633686 s    middle o
# 9  OM8SR  -0.4360247 -0.20818208 s    zlate  o
# 10 WH1SR   1.1705243 -0.20484016 s    early  w
# 11 WH2SR   1.1727248 -0.18026052 s    middle w
# 12 WH4SR   1.2103661 -0.12768851 s    zlate  w
# 13 OM2LR  -0.8959800 -0.10860714 zl   early  o
# 14 OM8LR  -0.1314585  0.13376352 zl   zlate  o
# 15 OM4LR  -0.2026880  0.72480246 zl   middle o
# 16 WH1LR   1.1857734 -0.10566253 zl   early  w
# 17 WH2LR   1.1962922 -0.07213338 zl   middle w
# 18 WH4LR   1.1769055 -0.07185685 zl   zlate  w

# %%
# make MDS plot
options(repr.plot.width=10, repr.plot.height=10)

ggplot(compare_mds, aes(x = MDS1, y = MDS2, color=cheese, shape=age, size=tech)) +
  geom_point() + 
  theme_classic()+
scale_color_manual(values = c("royalblue1","hotpink","springgreen4"))+scale_shape_manual(values=c(15,17,18))+scale_size_manual(values=c(2,4))
# Out:
# plot without title

# %% [markdown]
# ### Look at taxonomy over time

# %%
#Import timedf file listing query_names and their relative ages
timedf=suppressWarnings(read.csv("~/Desktop/whitime.csv"))
timedf
#Use Sys.glob to make taxdf file from the three tax annotate files for cheese WH
taxdf=read_taxonomy_annotate(Sys.glob("~/Downloads/untitled folder 2/whi*sr.with-lineages.csv"),intersect_bp_threshold=50000)
#Use Sys.glob to make taxdf file from the three tax annotate files for cheese WH
options(repr.plot.width=15, repr.plot.height=7)
plot=plot_taxonomy_annotate_ts_alluvial(taxdf,timedf,tax_glom_level="species",palette = accent_v2)
plot+theme(legend.position ="bottom")
# Out:
#   query_name time
# 1 whi1sr     1
# 2 whi2sr     2
# 3 whi4sr     4
# plot without title

# %%
#Import timedf file listing query_names and their relative ages
timedf=suppressWarnings(read.csv("~/Desktop/eltime.csv"))
timedf
#Use Sys.glob to make taxdf file from the three tax annotate files for cheese EL
taxdf=read_taxonomy_annotate(Sys.glob("~/Downloads/untitled folder 2/el*sr.with-lineages.csv"),intersect_bp_threshold=50000)
#Use Sys.glob to make taxdf file from the three tax annotate files for cheese EL
options(repr.plot.width=15, repr.plot.height=7)
plot=plot_taxonomy_annotate_ts_alluvial(taxdf,timedf,tax_glom_level="species",palette = accent_v2)
plot+theme(legend.position ="bottom")
# Out:
#   query_name time
# 1 el2sr      0.5
# 2 el4sr      1.0
# 3 el12sr     3.0
# plot without title

# %%
#Import timedf file listing query_names and their relative ages
timedf=suppressWarnings(read.csv("~/Desktop/omtime.csv"))
timedf
#Use Sys.glob to make taxdf file from the three tax annotate files for cheese WH
taxdf=read_taxonomy_annotate(Sys.glob("~/Downloads/untitled folder 2/oma*sr.with-lineages.csv"),intersect_bp_threshold=50000)
#Use Sys.glob to make taxdf file from the three tax annotate files for cheese WH
options(repr.plot.width=15, repr.plot.height=7)
plot=plot_taxonomy_annotate_ts_alluvial(taxdf,timedf,tax_glom_level="species",palette = accent_v2)
plot+theme(legend.position ="bottom")
# Out:
#   query_name time
# 1 om2sr      0.5
# 2 om4sr      1.0
# 3 oma8sr     2.0
# plot without title

# %% [markdown]
# # Summary of predicted viruses in long-read-time-series data
#
# Viral prediction for the OM2W, OM4W, OM8W, EL2W, EL4W, EL12W, WH1M, WH2M, and WH4M long read metagenomic assemblies was done using GeNomad 1.2.0 with database v1.1 and CheckV 1.0.1 with database v1.4. The end-to-end analysis pipeline was used for both. For GeNomad, only sequences with a virus/plasmid score higher than 0.7 were reported by the pipeline. Only viruses with a CheckV completeness higher than 50 were counted.

# %%
#read-in data and plot
options(scipen = 999)
vir=read.csv("~/Desktop/viralpred.csv")
vir
options(repr.plot.width=15, repr.plot.height=7)
p=ggplot(vir, aes(x=cond,y=size,fill=type)) + geom_bar(position=position_dodge2(width = 0.9, preserve = "single"), stat="identity")
p+scale_fill_manual(values = c("#F7B846","#5088C5","#F28360"))+labs(y= "Number of Predicted Phage", x = "Sample")
# Out:
#    cond size type
# 1  OM2   9   provirus
# 2  OM2   3   linear
# 3  OM4   7   provirus
# 4  OM4   2   linear
# 5  OM8   1   dtr
# 6  OM8  11   provirus
# 7  OM8   3   linear
# 8  EL2   6   provirus
# 9  EL2   4   linear
# 10 EL4  10   provirus
# 11 EL4   7   linear
# 12 EL8  14   provirus
# 13 EL8   9   linear
# 14 W1   15   provirus
# 15 W1   30   linear
# 16 W2    8   provirus
# 17 W2   18   linear
# 18 W4    1   dtr
# 19 W4   10   provirus
# 20 W4   19   linear
# plot without title
